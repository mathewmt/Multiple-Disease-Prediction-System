# %% [markdown]
# # Title: AIDI 1002 Final Term Project Report-----   Multiple Disease Prediction System
#
# #### Mathew Mukalel Thomas  --- 200574725
# #### Muhammad Ahmed  --- 200565713

# %% [markdown]
# # Introduction:
#
# #### Problem Description:
#
# User
# Disease  Prediction  using  Machine  Learning  is  the  system  that  is  used  to  predict  the  diseases  from  the symptoms which are given by the patients or any user. The system processes the symptoms provided by the user  as input  and  gives the  output as  the probability  of the  disease.  Naïve  Bayes  classifier  is used  in the prediction of the disease which is a supervised machine learning algorithm. The probability of the disease is calculated  by  the  Naïve  Bayes  algorithm.  With  an  increase  in  biomedical  and  healthcare  data,  accurate analysis  of  medical  data  benefits  early  disease  detection  and  patient  care.  By  using  linear  regression  and decision tree we are predicting diseases like Diabetes, Malaria, Jaundice, Dengue, and Tuberculosis.
#
# #### Context of the Problem:
#
#
# The topic of "Disease Prediction using Machine Learning" is important for several reasons, contributing to advancements in healthcare and disease management. Here are some key reasons why this topic is significant:
#
# Early Detection and Prevention:
#
# Disease prediction models enable the early detection of medical conditions based on symptoms or risk factors.
# Early detection is crucial for initiating timely interventions and treatments, often leading to better outcomes and increased chances of successful recovery.
#
# Improved Patient Care:
#
# Predictive models provide healthcare professionals with valuable insights into potential health issues, allowing for personalized and targeted care plans.
# Customized treatments based on predictive analytics can enhance patient outcomes and overall healthcare quality.
#
#
# Reducing Healthcare Costs:
#
# Early detection and prevention can lead to a reduction in healthcare costs associated with treating advanced-stage diseases.
# Preventive measures are often more cost-effective than treating diseases in their later stages.
# Research and Development:
#
# The development and deployment of machine learning models in healthcare contribute to ongoing research and advancements in medical science.
# These models provide valuable insights that can guide future research and improve our understanding of various diseases.
#
# #### Limitation About other Approaches:
#
# This modification allows you to include the decision function score in the prediction output, providing more information about the model's confidence or certainty in its prediction. Adjustments can be made based on the characteristics and capabilities of your new model.
#
# #### Solution:
#
# The decision function score is a concept commonly used in binary classification models, such as Support Vector Machines (SVM) and some variants of logistic regression. The decision function outputs a continuous score for each sample, and this score is then used to make a prediction.

# %% [markdown]
# # Background
#
# Explain the related work using the following table
#
# | Reference |Explanation |  Dataset/Input |Weakness
# | --- | --- | --- | --- |
# | Tom et al. [1] | They trained a BERT based transformer to predict answers from the passage of a question| SQUAD dataset for QA | Only 80% accuracy
# | Heart Disease Prediction [2] | Utilizes a machine learning model for heart disease prediction based on user input features| Custom dataset for heart disease prediction | Future improvement: Exploration of interpretability features in the model output, such as feature importance or visualization, to enhance user understanding. Additionally, consideration of incorporating more diverse and extensive datasets for robust evaluation and generalizability
#
#
# The last row in this table should be about the method discussed in this paper (If you can't find the weakenss of this method then write about the future improvement, see the future work section of the paper)

# %% [markdown]
# # Methodology
#
# Here we are going to explain the existing model
#
# Model Loading:
#
# The application loads pre-trained machine learning models for diabetes, heart disease, and Parkinson's disease using the pickle module. These models have been previously trained on relevant datasets to make predictions based on specific input features.
# Streamlit Sidebar and Option Menu:
#
# The Streamlit sidebar is used to provide a user-friendly navigation experience. An option menu is included to allow users to choose between different disease prediction categories: "Diabetes Prediction," "Heart Disease Prediction," and "Parkinson's Prediction." Users can easily switch between these prediction modes.
# Diabetes Prediction Page:
#
# If the user selects "Diabetes Prediction," the application presents input fields related to diabetes risk factors, such as the number of pregnancies, glucose level, blood pressure, and others. A button is available to trigger the prediction process. Once clicked, the application uses the pre-trained diabetes model to predict whether the user is diabetic or not based on the provided input. The result is then displayed to the user.
# Heart Disease Prediction Page:
#
# For "Heart Disease Prediction," the application prompts the user to input various factors related to heart health, including age, sex, chest pain types, and more. Similar to the diabetes prediction page, a button triggers the prediction process. The application utilizes the pre-trained heart disease model to predict the likelihood of the user having heart disease and displays the result accordingly.
# Parkinson's Prediction Page:
#
# In the "Parkinson's Prediction" section, users are asked to input voice-related features. The application then uses the pre-trained Parkinson's disease model to predict whether the user has Parkinson's disease or not. The result is presented to the user after clicking the prediction button.
# Prediction Process:
#
# The prediction process involves taking user inputs, processing them through the respective machine learning model, and obtaining a prediction outcome. The application communicates this outcome to the user, indicating the likelihood of having the specific disease based on the input features.
# Error Handling:
#
# To ensure a robust user experience, the application includes error handling. In case of any unexpected issues during the prediction process, error messages are displayed to inform the user about the problem, ensuring transparency and user awareness.
# In summary, the application provides an interactive and intuitive interface for users to input relevant health information and receive predictions for diabetes, heart disease, and Parkinson's disease. It leverages pre-trained machine learning models to make these predictions, aiming to assist users in understanding their potential health risks.

# %% [markdown]
# # Implementation
#
# In this section, you will provide the code and its explanation. You may have to create more cells after this. (To keep the Notebook clean, do not display debugging output or thousands of print statements from hundreds of epochs. Make sure it is readable for others by reviewing it yourself carefully.)

# %% [markdown]
# ### This is original code

# %%
# -*- coding: utf-8 -*-


import pickle
import streamlit as st
from streamlit_option_menu import option_menu


# loading the saved models

diabetes_model = pickle.load(open('C:/Users/PERSONAL/Desktop/My Docs/ME/Multiple Disease Prediction System/saved models/diabetes_model.sav', 'rb'))

heart_disease_model = pickle.load(open('C:/Users/PERSONAL/Desktop/My Docs/ME/Multiple Disease Prediction System/saved models/heart_disease_model.sav','rb'))

parkinsons_model = pickle.load(open('C:/Users/PERSONAL/Desktop/My Docs/ME/Multiple Disease Prediction System/saved models/parkinsons_model.sav', 'rb'))



# sidebar for navigation
with st.sidebar:
    
    selected = option_menu('Multiple Disease Prediction System',
                          
                          ['Diabetes Prediction',
                           'Heart Disease Prediction',
                           'Parkinsons Prediction'],
                          icons=['activity','heart','person'],
                          default_index=0)
    
    
# Diabetes Prediction Page
if (selected == 'Diabetes Prediction'):
    
    # page title
    st.title('Diabetes Prediction using ML')
    
    
    # getting the input data from the user
    col1, col2, col3 = st.columns(3)
    
    with col1:
        Pregnancies = st.text_input('Number of Pregnancies')
        
    with col2:
        Glucose = st.text_input('Glucose Level')
    
    with col3:
        BloodPressure = st.text_input('Blood Pressure value')
    
    with col1:
        SkinThickness = st.text_input('Skin Thickness value')
    
    with col2:
        Insulin = st.text_input('Insulin Level')
    
    with col3:
        BMI = st.text_input('BMI value')
    
    with col1:
        DiabetesPedigreeFunction = st.text_input('Diabetes Pedigree Function value')
    
    with col2:
        Age = st.text_input('Age of the Person')
    
    
    # code for Prediction
    diab_diagnosis = ''
    
    # creating a button for Prediction
    
    if st.button('Diabetes Test Result'):
        diab_prediction = diabetes_model.predict([[Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age]])
        
        if (diab_prediction[0] == 1):
          diab_diagnosis = 'The person is diabetic'
        else:
          diab_diagnosis = 'The person is not diabetic'
        
    st.success(diab_diagnosis)




# Heart Disease Prediction Page
if (selected == 'Heart Disease Prediction'):
    
    # page title
    st.title('Heart Disease Prediction using ML')
    
    col1, col2, col3 = st.columns(3)
    
    with col1:
        age = st.text_input('Age')
        
    with col2:
        sex = st.text_input('Sex')
        
    with col3:
        cp = st.text_input('Chest Pain types')
        
    with col1:
        trestbps = st.text_input('Resting Blood Pressure')
        
    with col2:
        chol = st.text_input('Serum Cholestoral in mg/dl')
        
    with col3:
        fbs = st.text_input('Fasting Blood Sugar > 120 mg/dl')
        
    with col1:
        restecg = st.text_input('Resting Electrocardiographic results')
        
    with col2:
        thalach = st.text_input('Maximum Heart Rate achieved')
        
    with col3:
        exang = st.text_input('Exercise Induced Angina')
        
    with col1:
        oldpeak = st.text_input('ST depression induced by exercise')
        
    with col2:
        slope = st.text_input('Slope of the peak exercise ST segment')
        
    with col3:
        ca = st.text_input('Major vessels colored by flourosopy')
        
    with col1:
        thal = st.text_input('thal: 0 = normal; 1 = fixed defect; 2 = reversable defect')
        
        
     
     
    # code for Prediction
    heart_diagnosis = ''
    
    # creating a button for Prediction
    
    if st.button('Heart Disease Test Result'):
        heart_prediction = heart_disease_model.predict([[age, sex, cp, trestbps, chol, fbs, restecg,thalach,exang,oldpeak,slope,ca,thal]])                          
        
        if (heart_prediction[0] == 1):
          heart_diagnosis = 'The person is having heart disease'
        else:
          heart_diagnosis = 'The person does not have any heart disease'
        
    st.success(heart_diagnosis)
        
    
    

# Parkinson's Prediction Page
if (selected == "Parkinsons Prediction"):
    
    # page title
    st.title("Parkinson's Disease Prediction using ML")
    
    col1, col2, col3, col4, col5 = st.columns(5)  
    
    with col1:
        fo = st.text_input('MDVP:Fo(Hz)')
        
    with col2:
        fhi = st.text_input('MDVP:Fhi(Hz)')
        
    with col3:
        flo = st.text_input('MDVP:Flo(Hz)')
        
    with col4:
        Jitter_percent = st.text_input('MDVP:Jitter(%)')
        
    with col5:
        Jitter_Abs = st.text_input('MDVP:Jitter(Abs)')
        
    with col1:
        RAP = st.text_input('MDVP:RAP')
        
    with col2:
        PPQ = st.text_input('MDVP:PPQ')
        
    with col3:
        DDP = st.text_input('Jitter:DDP')
        
    with col4:
        Shimmer = st.text_input('MDVP:Shimmer')
        
    with col5:
        Shimmer_dB = st.text_input('MDVP:Shimmer(dB)')
        
    with col1:
        APQ3 = st.text_input('Shimmer:APQ3')
        
    with col2:
        APQ5 = st.text_input('Shimmer:APQ5')
        
    with col3:
        APQ = st.text_input('MDVP:APQ')
        
    with col4:
        DDA = st.text_input('Shimmer:DDA')
        
    with col5:
        NHR = st.text_input('NHR')
        
    with col1:
        HNR = st.text_input('HNR')
        
    with col2:
        RPDE = st.text_input('RPDE')
        
    with col3:
        DFA = st.text_input('DFA')
        
    with col4:
        spread1 = st.text_input('spread1')
        
    with col5:
        spread2 = st.text_input('spread2')
        
    with col1:
        D2 = st.text_input('D2')
        
    with col2:
        PPE = st.text_input('PPE')
        
    
    
    # code for Prediction
    parkinsons_diagnosis = ''
    
    # creating a button for Prediction    
    if st.button("Parkinson's Test Result"):
        parkinsons_prediction = parkinsons_model.predict([[fo, fhi, flo, Jitter_percent, Jitter_Abs, RAP, PPQ,DDP,Shimmer,Shimmer_dB,APQ3,APQ5,APQ,DDA,NHR,HNR,RPDE,DFA,spread1,spread2,D2,PPE]])                          
        
        if (parkinsons_prediction[0] == 1):
          parkinsons_diagnosis = "The person has Parkinson's disease"
        else:
          parkinsons_diagnosis = "The person does not have Parkinson's disease"
        
    st.success(parkinsons_diagnosis)

# %% [markdown]
# #### In this model we createdmade  some updation to ensure better prediction

# %% [markdown]
# **This code segment allows users to input specific health features related to diabetes**
#
# **The original code  has a few limitations**
#
# Lack of Input Validation:
#
# The original code does not include explicit validation of input values. If a user enters non-numeric values or there are other issues with the input, it may lead to errors during the prediction process.
#
# No Display of Decision Function Score:
#
# The original code does not display the decision function score, which represents the model's confidence in its prediction.

# %%
# Code cells

 creating a button for Prediction
    
    if st.button('Diabetes Test Result'):
        diab_prediction = diabetes_model.predict([[Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age]])
        
        if (diab_prediction[0] == 1):
          diab_diagnosis = 'The person is diabetic'
        else:
          diab_diagnosis = 'The person is not diabetic'
        
    st.success(diab_diagnosis)

# %% [markdown]
# ### This is the Updated model

# %%
# Creating a button for Prediction
if st.button('Diabetes Test Result'):
    try:
        # Validate input values
        input_values = [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age]
        float_inputs = [float(val) for val in input_values]  # Convert to float
        diab_prediction, decision_function_score = diabetes_model.predict([float_inputs]), diabetes_model.decision_function([float_inputs])

        # Display prediction result
        if diab_prediction[0] == 1:
            diab_diagnosis = f'The person is diabetic with a decision function score of {decision_function_score[0]:.2f}'
        else:
            diab_diagnosis = f'The person is not diabetic with a decision function score of {decision_function_score[0]:.2f}'

    except Exception as e:
        st.error(f"Error during prediction: {e}")
        diab_diagnosis = 'Error occurred during prediction.'

st.success(diab_diagnosis)

# %% [markdown]
# ### The updated code brings several changes and benefits:
#
# #### Validation of Input Values:
# The code includes a try-except block to validate the input values before making predictions. It ensures that the input values are convertible to floats, addressing potential issues related to incorrect or non-numeric inputs.
#
# #### Decision Function Score Display:
# The code introduces the decision_function_score variable, which represents the decision function score of the prediction. This score provides additional information about the model's confidence in its prediction
#
# Displaying the decision function score adds transparency to the prediction outcome. Users can now see a numerical score indicating how confident the model is in its prediction. This can be valuable for users who want more insight into the model's reasoning
#
# The code maintains the use of Streamlit's st.success for displaying the prediction outcome. This ensures consistency in the presentation style across different sections of the application
#
# These changes enhance the reliability of the application by validating input values, providing additional information about the model's confidence, and improving error handling. The decision function score contributes to a more transparent and informative user experience.

# %% [markdown]
# # Conclusion and Future Direction
#
# In conclusion, the updates made to the original code enhance the reliability, transparency, and user-friendliness of the Multiple Disease Prediction System. The inclusion of input validation, display of decision function scores, and improved error handling contribute to a more robust application. Users now benefit from additional insights into the model's confidence, and potential issues with input data are addressed more gracefully.
#
# Future Directions:
#
# Model Exploration and Comparison:
#
# Explore and experiment with additional machine learning models beyond the existing ones (Diabetes, Heart Disease, Parkinson's). Consider introducing new models or updating existing ones based on the latest research findings to improve overall prediction accuracy.
# Parameter Tuning:
#
# Conduct a comprehensive parameter tuning exercise for the existing models to optimize their performance. Adjust hyperparameters, such as learning rates, regularization terms, and tree depths, to identify the most effective configurations for each model.
# Feature Engineering:
#
# Investigate the possibility of incorporating new features or refining existing ones to enhance the predictive power of the models. Feature engineering techniques, such as creating interaction terms or selecting more relevant features, can contribute to improved model performance

# %% [markdown]
# # References:
#
# [1]: Dr C K Gomathy, Mr. A. Rohith Naidu Sri Chandrasekharendra Saraswathi Viswa Mahavidyalaya , Kanchipuram
